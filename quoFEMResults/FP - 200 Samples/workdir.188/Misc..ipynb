# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 39.99, 0.005)
y = np.genfromtxt('RSN766_G02_000_VEL.txt')

plt.plot(x, y)
print(x[1])
# Out:
# 0.005

# %%
list49 = np.genfromtxt('displacement.out', usecols = (1))
max49 = np.max(np.absolute(list49))
print(max49)

list50 = np.genfromtxt('displacement.out', usecols = (2))
max50 = np.max(np.absolute(list50))
print(max50)
# Out:
# 0.177734
# 0.177734
